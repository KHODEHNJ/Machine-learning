# %%
# !kaggle datasets download andonians/random-linear-regression
# Out:
# Dataset URL: https://www.kaggle.com/datasets/andonians/random-linear-regression
# License(s): other
# random-linear-regression.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile
zip_ref = zipfile.ZipFile('random-linear-regression.zip', 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import pandas as pd
x = pd.read_csv('train.csv')
y = pd.read_csv('test.csv')

# %%
x
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
y
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
x.dropna(inplace=True)

# %%
x_train = x.iloc[:, :-1]

# %%
y_train = x.iloc[:, -1]

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_train,y_train)
# Out:
# 0.9907015319025518

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='green')
plt.plot(x_train,reg.predict(x_train),color='yellow')
plt.title('Linear Regression')
plt.xlabel('x' , color="red")
plt.ylabel('y' , color="blue")
plt.legend()
plt.show()
# Out:
# <ipython-input-50-137e2300235a>:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
