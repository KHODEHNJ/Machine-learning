# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data = pd.read_csv('https://raw.githubusercontent.com/FARIDDD123/machine-learning/refs/heads/main/Social_Network_Ads.csv')
data
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
X = data.iloc[:, :-1].values
y = data.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
x_test = sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
classifier.score(X_test,y_test)
# Out:
# 0.32

# %%
y_pred = classifier.predict(X_test)

# %%
plt.figure(figsize=(8, 6))
not_purchased = data[data['Purchased'] == 0]
purchased = data[data['Purchased'] == 1]
plt.scatter(not_purchased['Age'], not_purchased['EstimatedSalary'], c='blue', label='Not Purchased (0)', edgecolor='k')
plt.scatter(purchased['Age'], purchased['EstimatedSalary'], c='red', label='Purchased (1)', edgecolor='k')
plt.title('Simple Visualization of Social Network Ads Data')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend(title='Purchased', loc='upper right')
plt.show()
